# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 3, 2, 10])
ypoints = np.array([6, 12, 18, 20])

plt.plot(xpoints, ypoints, color = 'r', marker="o", mfc = 'g', mec='g', linestyle = 'dotted')

plt.show()
